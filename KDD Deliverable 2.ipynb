# %%
#KDD Project Deliverable 2 Updated

# %%
#importing module
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv
from pathlib import Path
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
'''
Data Cleansing Steps:
-Unnecessary Column Deletion
-Missing Values Check
-Column Naming Convention
-Duplicate Value Evaluation
-Null Values Evaluation
'''
# Out:
# '\nData Cleansing Steps:\n1)Remove Repeated Row \n2)Missing value treatment \n3)Removal of Irrelevant Data \n4)Manual error while typing \n5)Renaming Columns \n'

# %%
data = pd.read_csv("C:\\Users\\asuriakanth\\Desktop\\FAO.csv", encoding=('ISO-8859-1'), 
                  low_memory = False)
data
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  \
# 0                   AFG          2  Afghanistan       2511
# 1                   AFG          2  Afghanistan       2805
# 2                   AFG          2  Afghanistan       2513
# 3                   AFG          2  Afghanistan       2513
# 4                   AFG          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472               ZWE        181     Zimbabwe       2948
# 21473               ZWE        181     Zimbabwe       2960
# 21474               ZWE        181     Zimbabwe       2960
# 21475               ZWE        181     Zimbabwe       2961
# 21476               ZWE        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# ...

# %%
print(data)
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  \
# 0                   AFG          2  Afghanistan       2511
# 1                   AFG          2  Afghanistan       2805
# 2                   AFG          2  Afghanistan       2513
# 3                   AFG          2  Afghanistan       2513
# 4                   AFG          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472               ZWE        181     Zimbabwe       2948
# 21473               ZWE        181     Zimbabwe       2960
# 21474               ZWE        181     Zimbabwe       2960
# 21475               ZWE        181     Zimbabwe       2961
# 21476               ZWE        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# ...

# %%
data.head()
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# 3       Barley and products          5142    Food  1000 tonnes     33.94
# 4        Maize and products          5521    Feed  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# ...

# %%
'''
Delete unnecessary columns by defining list with columns to drop. we call the drop() function 
on our object, passing in the inplace parameter as True and the axis parameter as 1
'''
data.drop(['latitude','longitude', 'Area Abbreviation'],axis=1 ,inplace=True)

# %%
#Columns are dropped
data.head()
# Out:
#    Area Code         Area  Item Code                      Item  Element Code  \
# 0          2  Afghanistan       2511        Wheat and products          5142
# 1          2  Afghanistan       2805  Rice (Milled Equivalent)          5142
# 2          2  Afghanistan       2513       Barley and products          5521
# 3          2  Afghanistan       2513       Barley and products          5142
# 4          2  Afghanistan       2514        Maize and products          5521
#
#   Element         Unit   Y1961   Y1962   Y1963  ...   Y2004   Y2005   Y2006  \
# 0    Food  1000 tonnes  1928.0  1904.0  1666.0  ...  3249.0  3486.0  3704.0
# 1    Food  1000 tonnes   183.0   183.0   182.0  ...   419.0   445.0   546.0
# 2    Feed  1000 tonnes    76.0    76.0    76.0  ...    58.0   236.0   262.0
# 3    Food  1000 tonnes   237.0   237.0   237.0  ...   185.0    43.0    44.0
# 4    Feed  1000 tonnes   210.0   210.0   214.0  ...   120.0   208.0   233.0
#
# ...

# %%
'''
Check for missing values  
'''
#no missing data values, so no need to drop it or fill with other arbitrary value
missing = data.isnull() 
print(missing)
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 21472      False  False      False  False         False    False  False
# 21473      False  False      False  False         False    False  False
# 21474      False  False      False  False         False    False  False
# 21475      False  False      False  False         False    False  False
# 21476      False  False      False  False         False    False  False
#
#        Y1961  Y1962  Y1963  ...  Y2004  Y2005  Y2006  Y2007  Y2008  Y2009  \
# ...

# %%
'''
Column Renaming: Columns mentioned here have appropriate naming conventions so need to rename 
'''
# Out:
# '\nColumn Renaming: Columns mentioned here have appropriate naming conventions so need to rename \n'

# %%
'''
Checking for duplicate rows/values based on all columns in 'data' dataframe  by using duplicated() 
function
'''
data.duplicated()

#no duplicated rows present in dataframes
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21472    False
# 21473    False
# 21474    False
# 21475    False
# 21476    False
# Length: 21477, dtype: bool

# %%
'''
Null Value Evaluation
'''
data.isnull()
#no null values present
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 21472      False  False      False  False         False    False  False
# 21473      False  False      False  False         False    False  False
# 21474      False  False      False  False         False    False  False
# 21475      False  False      False  False         False    False  False
# 21476      False  False      False  False         False    False  False
#
#        Y1961  Y1962  Y1963  ...  Y2004  Y2005  Y2006  Y2007  Y2008  Y2009  \
# ...

# %%
data.shape
# Out:
# (21477, 60)

# %%
'''
Standardization/Normalization
'''
scaler = StandardScaler()
scaler.fit()

# %%
'''
Preliminary Data Analysis - In Progress  (taking a stab at initial list of research questions)
'''
# Out:
# '\nPreliminary Data Analysis - In Progress \n'

# %%
# Want to see top 20 food feed production for 1961 as this will help to determine top 5 foods produced
#by each continent in that year
top_20 = data.nlargest(20, 'Y1961')
top_20
# Out:
#        Area Code                      Area  Item Code  \
# 20506        231  United States of America       2905
# 20399        231  United States of America       2514
# 4239          41           China, mainland       2907
# 4143          41           China, mainland       2533
# 9139         100                     India       2905
# 4237          41           China, mainland       2905
# 4249          41           China, mainland       2918
# 20493        231  United States of America       2848
# 20531        231  United States of America       2948
# 4186          41           China, mainland       2605
# 9036         100                     India       2805
# 4123          41           China, mainland       2805
# 15405        173                    Poland       2531
# 15496        173                    Poland       2907
# 4236          41           China, mainland       2905
# 20518        231  United States of America       2918
# ...

# %%
#group datafram by Area (country)   --> helps in seeing how food production has evolved in that year
#based on the area

# group the data on country .
country_grouping = data.groupby('Area')
country_grouping.first()
# Out:
#                                     Area Code  Item Code                Item  \
# Area
# Afghanistan                                 2       2511  Wheat and products
# Albania                                     3       2511  Wheat and products
# Algeria                                     4       2511  Wheat and products
# Angola                                      7       2511  Wheat and products
# Antigua and Barbuda                         8       2511  Wheat and products
# ...                                       ...        ...                 ...
# Venezuela (Bolivarian Republic of)        236       2511  Wheat and products
# Viet Nam                                  237       2511  Wheat and products
# Yemen                                     249       2511  Wheat and products
# Zambia                                    251       2511  Wheat and products
# Zimbabwe                                  181       2511  Wheat and products
#
# ...
